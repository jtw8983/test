# %% [markdown]
# ## 문제 1
#
# 다음 계산 결과를 출력하시오.
#
# a = 10
# b = 3
#
#
# a를 b로 나눈 몫
#
# a를 b로 나눈 나머지

# %%
a = 10
b = 3
a // b
# Out:
# 3

# %%
a = 10
b = 3
a % b
# Out:
# 1

# %% [markdown]
# ## 문제 2 다음 코드의 출력 결과는 무엇인가?
#
#
#
# <!-- print(2 ** 3) -->

# %%
print(2 ** 3)
# Out:
# 8

# %% [markdown]
# ## 문제 3 아래 변수들을 이용해 총합과 평균을 구하시오.
#
# kor = 80
# eng = 75
# math = 90
#
#
# 평균은 소수점까지 출력

# %%
kor = 80
eng = 75
math = 55

total = kor + eng + math
average = total / 3

print("총점 : ", total)
print("평균 : ", average)
# Out:
# 총점 :  210
# 평균 :  70.0

# %% [markdown]
#  ## 문제 4
#
# 다음 코드의 결과는?
#
# a = 7
#
# a += 3
#
# a *= 2
#
# print(a)

# %%
a = 7
a += 3
a *= 2
print(a)
# Out:
# 20
